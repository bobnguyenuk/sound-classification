# %%
import numpy as np
features=np.load("20features.npy")

# %%
labels=np.hstack((np.zeros((100,),dtype=int),np.ones((100,),dtype=int)))

# %%
from sklearn.model_selection import cross_val_score, StratifiedShuffleSplit
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
# Logistic Regression classifier
clf=LogisticRegression(max_iter = 300)
# Decision Tree classifier
clf_tree = DecisionTreeClassifier()
# Random Forest classifier
clf_forest = RandomForestClassifier(n_estimators=100)
# Support Vector Machine classifier, linear kernel
svm_l = SVC(C=100, kernel = 'linear')
# Support Vector Machine classifier, polynomial kernel
svm_p = SVC(C=100, kernel = 'poly')
# Support Vector Machine classifier, rbf kernel
svm_r = SVC(C=100, kernel = 'rbf')
# Gaussian Naive Bayes classifier
clf_nb=GaussianNB()

# %%
np.random.seed(1)
# number of test case
tc = 5
sss = StratifiedShuffleSplit(n_splits=tc, test_size=.3, random_state=1)
sss.get_n_splits(features, labels)
for train_index, test_index in sss.split(features, labels):
    print ('!--------------------!--------------------!--------------------!--------------------!--------------------!')
    print("Test using:", test_index)
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Decision Tree
    print ("-------------------- Decision Tree classifier: --------------------")
    clf_tree.fit(X_train, y_train)
    y_pred = clf_tree.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
#     # Cross-validation 5 folds
#     accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
#     print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
#     # Random Forest
#     print ("-------------------- Random Forest classifier: --------------------")
#     clf_forest.fit(X_train, y_train)
#     y_pred = clf_forest.predict(X_test)
    
#     print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
#     print(metrics.confusion_matrix(y_test,y_pred))
#     # Cross-validation 10 folds
#     accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
#     print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
#     # Cross-validation 10 folds
#     accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
#     print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
#     # SVM Linear
#     print ("-------------------- SVM classifier, linear kernel: --------------------")
#     svm_l.fit(X_train, y_train)
#     y_pred = svm_l.predict(X_test)
    
#     print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
#     print(metrics.confusion_matrix(y_test,y_pred))
#     # Cross-validation 10 folds
#     accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
#     print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
#     # Cross-validation 10 folds
#     accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
#     print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
#     # SVM Poly
#     print ("-------------------- SVM classifier, polynomial kernel: --------------------")
#     svm_p.fit(X_train, y_train)
#     y_pred = svm_p.predict(X_test)
    
#     print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
#     print(metrics.confusion_matrix(y_test,y_pred))
#     # Cross-validation 10 folds
#     accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
#     print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
#     # Cross-validation 10 folds
#     accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
#     print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
#     # SVM RBF
#     print ("-------------------- SVM classifier, RBF function kernel: --------------------")
#     svm_r.fit(X_train, y_train)
#     y_pred = svm_r.predict(X_test)
    
#     print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
#     print(metrics.confusion_matrix(y_test,y_pred))
#     # Cross-validation 10 folds
#     accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
#     print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
#     # Cross-validation 10 folds
#     accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
#     print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
# Out:
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 50 185  96  68 184 106 145 177  22 190 123 143 130 113   9 120  72 175
#   85 124  20 194   7  16 136   6 170 102  75   1  29 107 112  25  28  71
#  191  37   5  14 132  12  61 152  79 110  18 176 172 193  76 157 168  11
#   13  63 121 181  64  57]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.62
# [[19 11]
#  [12 18]]
# 10 fold cross-validation -> Accuracy: 0.58
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 58 186 137  75 127  26  11 194 143 177 121 105 134  16 162  42  70 178
#    6 119  63   2 138  52 133  98  49 107 104 140 190  37  78  35  21  95
#  139 108  86 167 130 169  18   0 151  28 182 181 179  36 142 148  14  27
#  146  22  50  94  32  97]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.53
# [[12 18]
#  [10 20]]
# 10 fold cross-validation -> Accuracy: 0.62
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [103 175 154 166 107  30  18 104 167  41  32 174  39 191 132   7  38 190
#  113 196 138 156  88 184  79  89 111  81  37 173 131 159 105  50   1  49
#   77 199  82 126  12  91  15  21 197 108  36 101  96 170  83 176 193  47
#   69 181  42  95  51  43]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.63
# [[21  9]
#  [13 17]]
# 10 fold cross-validation -> Accuracy: 0.58
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [188 155 185  15 107  61  34 131  67 170   3  62 174  21 175  95  47   8
#  121 199  72 158  68 145  23 114  10 162  16  56 115  94 179 146  29  24
#  102 156  18  57 126  82  26  55 133 118 117 194   7 101  22 152 143 176
#   42 169 183  12  35  31]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.67
# [[22  8]
#  [12 18]]
# 10 fold cross-validation -> Accuracy: 0.62
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [159 141 166 125  66  43  29  13  21 154  85  46  87  44 104 107  28 134
#   54  71  76 127 161 199   3  67 149  17 152 151 198 135 130  20  23 111
#  184  32  84  30  63  52  22  57 110 156 185 113 181  31  59  12 160 194
#   25  50 108 121 114 180]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.62
# [[16 14]
#  [ 9 21]]
# 10 fold cross-validation -> Accuracy: 0.66

# %%
np.random.seed(1)
# number of test case
tc = 5
sss = StratifiedShuffleSplit(n_splits=tc, test_size=.25, random_state=1)
sss.get_n_splits(features, labels)
for train_index, test_index in sss.split(features, labels):
    print ('!--------------------!--------------------!--------------------!--------------------!--------------------!')
    print("Test using:", test_index)
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Decision Tree
    print ("-------------------- Decision Tree classifier: --------------------")
    clf_tree.fit(X_train, y_train)
    y_pred = clf_tree.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # Random Forest
    print ("-------------------- Random Forest classifier: --------------------")
    clf_forest.fit(X_train, y_train)
    y_pred = clf_forest.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # SVM Linear
    print ("-------------------- SVM classifier, linear kernel: --------------------")
    svm_l.fit(X_train, y_train)
    y_pred = svm_l.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # SVM Poly
    print ("-------------------- SVM classifier, polynomial kernel: --------------------")
    svm_p.fit(X_train, y_train)
    y_pred = svm_p.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # SVM RBF
    print ("-------------------- SVM classifier, RBF function kernel: --------------------")
    svm_r.fit(X_train, y_train)
    y_pred = svm_r.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
# Out:
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [123  50 172   1 106 110 193 120 152  29  96  11 130 136 185  28  13 107
#    5 102 176 113  85 191  18 143  76  71  14 177   9 170  64  75 145  16
#   25  79   6 168  37 175  20 190 121 157  68  72  12 194]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.58
# [[14 11]
#  [10 15]]
# 5 fold cross-validation -> Accuracy: 0.61
# 10 fold cross-validation -> Accuracy: 0.72
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.84
# [[20  5]
#  [ 3 22]]
# 5 fold cross-validation -> Accuracy: 0.61
# 10 fold cross-validation -> Accuracy: 0.79
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.70
# [[19  6]
#  [ 9 16]]
# 5 fold cross-validation -> Accuracy: 0.60
# 10 fold cross-validation -> Accuracy: 0.83
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.78
# [[19  6]
#  [ 5 20]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.75
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.82
# [[21  4]
#  [ 5 20]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.71
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 37 133 182 108  11 130  87   6  52 199  36 195  46 127 188  32 109 140
#   50  21  58   0 138 148 105  22 146  16 178 103  63 107  92  35 181 137
#   70 169 177  27  93 151 167  49  18 191  75  28 143  14]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.56
# [[12 13]
#  [ 9 16]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.71
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.82
# [[22  3]
#  [ 6 19]]
# 5 fold cross-validation -> Accuracy: 0.60
# 10 fold cross-validation -> Accuracy: 0.73
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.74
# [[17  8]
#  [ 5 20]]
# 5 fold cross-validation -> Accuracy: 0.57
# 10 fold cross-validation -> Accuracy: 0.75
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.70
# [[13 12]
#  [ 3 22]]
# 5 fold cross-validation -> Accuracy: 0.57
# 10 fold cross-validation -> Accuracy: 0.74
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.74
# [[16  9]
#  [ 4 21]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.76
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 83   1 167  12  94  30  89 159  47  64 101 193   7 143 105  39 174  21
#  153  85 142  97 131 111 100  37 103 126 166  90  32  15 139 113 148 190
#   57 157  18  38 188 195  52 156  77 154 175  19  42  36]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.70
# [[15 10]
#  [ 5 20]]
# 5 fold cross-validation -> Accuracy: 0.55
# 10 fold cross-validation -> Accuracy: 0.77
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.82
# [[22  3]
#  [ 6 19]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.81
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.58
# [[16  9]
#  [12 13]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.79
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.54
# [[12 13]
#  [10 15]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.73
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.68
# [[17  8]
#  [ 8 17]]
# 5 fold cross-validation -> Accuracy: 0.58
# 10 fold cross-validation -> Accuracy: 0.76
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 61  88 123  46  35 153  19  18  58 159  85 157 155  59 105   7  29 173
#  170   9 124 120  94  99  40 127  21  82  51 169  27 182 179 178 177 151
#  158 183 142  67 136  45   0 180 163  71  54  41 191 154]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.72
# [[18  7]
#  [ 7 18]]
# 5 fold cross-validation -> Accuracy: 0.68
# 10 fold cross-validation -> Accuracy: 0.77
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.82
# [[20  5]
#  [ 4 21]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.83
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.64
# [[14 11]
#  [ 7 18]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.77
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.62
# [[13 12]
#  [ 7 18]]
# 5 fold cross-validation -> Accuracy: 0.60
# 10 fold cross-validation -> Accuracy: 0.79
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.68
# [[14 11]
#  [ 5 20]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.83
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 70  53 131  83 125 174  49  21  30  28  32  81 187 149   1  37  73  76
#  183  48 109 123  40 163  34  99 111 193  82 168 142 140  86  80  88   0
#  195 190   3 169 105 188 118 196 179  33  22 138 146 132]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.70
# [[16  9]
#  [ 6 19]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.76
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.82
# [[24  1]
#  [ 8 17]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.80
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.74
# [[19  6]
#  [ 7 18]]
# 5 fold cross-validation -> Accuracy: 0.61
# 10 fold cross-validation -> Accuracy: 0.77
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.64
# [[16  9]
#  [ 9 16]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.75
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.74
# [[20  5]
#  [ 8 17]]
# 5 fold cross-validation -> Accuracy: 0.57
# 10 fold cross-validation -> Accuracy: 0.83

# %%
np.random.seed(1)
# number of test case
tc = 5
sss = StratifiedShuffleSplit(n_splits=tc, test_size=.2, random_state=1)
sss.get_n_splits(features, labels)
for train_index, test_index in sss.split(features, labels):
    print ('!--------------------!--------------------!--------------------!--------------------!--------------------!')
    print("Test using:", test_index)
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    
    # Decision Tree
    print ("-------------------- Decision Tree classifier: --------------------")
    clf_tree.fit(X_train, y_train)
    y_pred = clf_tree.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # Random Forest
    print ("-------------------- Random Forest classifier: --------------------")
    clf_forest.fit(X_train, y_train)
    y_pred = clf_forest.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # SVM Linear
    print ("-------------------- SVM classifier, linear kernel: --------------------")
    svm_l.fit(X_train, y_train)
    y_pred = svm_l.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # SVM Poly
    print ("-------------------- SVM classifier, polynomial kernel: --------------------")
    svm_p.fit(X_train, y_train)
    y_pred = svm_p.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
    
    # SVM RBF
    print ("-------------------- SVM classifier, RBF function kernel: --------------------")
    svm_r.fit(X_train, y_train)
    y_pred = svm_r.predict(X_test)
    
    print("Accuracy and confusion matrix: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test,y_pred))
    # Cross-validation 10 folds
    accuracies5 = cross_val_score(estimator = clf_tree, X = X_train, y = y_train, cv = 5)   
    print("5 fold cross-validation -> Accuracy: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10)    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
# Out:
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [143   1 106  75 185 194 152 176 130  50  29   6 191 121 136  25  28 120
#   37 172  76 193  18 175  71 102   5  79  20 177 190  11  72 145 107   9
#  170  16  12  64]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.55
# [[10 10]
#  [ 8 12]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.81
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.80
# [[17  3]
#  [ 5 15]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.73
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.65
# [[14  6]
#  [ 8 12]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.76
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.70
# [[14  6]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.61
# 10 fold cross-validation -> Accuracy: 0.78
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.78
# [[16  4]
#  [ 5 15]]
# 5 fold cross-validation -> Accuracy: 0.63
# 10 fold cross-validation -> Accuracy: 0.76
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [169 137 151  16 181  87  70  92  32 138  18  37 191 195  21 143  36 127
#  133  75 188  93  49  58 177 178   6 148 130 107  14  22  11 105  63 182
#  140   0  35 108]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.75
# [[15  5]
#  [ 5 15]]
# 5 fold cross-validation -> Accuracy: 0.57
# 10 fold cross-validation -> Accuracy: 0.73
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.88
# [[18  2]
#  [ 3 17]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.78
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.65
# [[13  7]
#  [ 7 13]]
# 5 fold cross-validation -> Accuracy: 0.60
# 10 fold cross-validation -> Accuracy: 0.76
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.68
# [[12  8]
#  [ 5 15]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.76
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.75
# [[13  7]
#  [ 3 17]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.78
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [103  89 105  47 174  21 111 153 190  42  38  57 131  15  77 100 126  65
#  139 143  37 157  12 142 167 195  52 166 148   1 193  19  64  80 159  85
#  175  83  39  18]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.70
# [[14  6]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.64
# 10 fold cross-validation -> Accuracy: 0.78
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.93
# [[19  1]
#  [ 2 18]]
# 5 fold cross-validation -> Accuracy: 0.61
# 10 fold cross-validation -> Accuracy: 0.81
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.57
# [[14  6]
#  [11  9]]
# 5 fold cross-validation -> Accuracy: 0.66
# 10 fold cross-validation -> Accuracy: 0.78
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.60
# [[14  6]
#  [10 10]]
# 5 fold cross-validation -> Accuracy: 0.66
# 10 fold cross-validation -> Accuracy: 0.78
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.72
# [[16  4]
#  [ 7 13]]
# 5 fold cross-validation -> Accuracy: 0.66
# 10 fold cross-validation -> Accuracy: 0.77
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [153  58 178  21  29 182  85  67  54   9  18  19 163 188 127 169  22 136
#   46  89 168  92 123  94 155   0  27  45 170  71 173 158 183 198 179 124
#  151 180  35  88]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.68
# [[13  7]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.54
# 10 fold cross-validation -> Accuracy: 0.81
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.78
# [[17  3]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.57
# 10 fold cross-validation -> Accuracy: 0.77
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.62
# [[13  7]
#  [ 8 12]]
# 5 fold cross-validation -> Accuracy: 0.49
# 10 fold cross-validation -> Accuracy: 0.79
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.62
# [[11  9]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.53
# 10 fold cross-validation -> Accuracy: 0.79
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.60
# [[11  9]
#  [ 7 13]]
# 5 fold cross-validation -> Accuracy: 0.53
# 10 fold cross-validation -> Accuracy: 0.79
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 33  99 118   1  48  82  40 142  53  81  80  76 188 193  32 163   0 174
#  179  28  21 187  22 123  88 146 138 140 111 132  83  73 109 131 190 169
#   30   3 105 195]
# -------------------- Decision Tree classifier: --------------------
# Accuracy and confusion matrix: 0.55
# [[13  7]
#  [11  9]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.81
# -------------------- Random Forest classifier: --------------------
# Accuracy and confusion matrix: 0.75
# [[18  2]
#  [ 8 12]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.80
# -------------------- SVM classifier, linear kernel: --------------------
# Accuracy and confusion matrix: 0.70
# [[15  5]
#  [ 7 13]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.77
# -------------------- SVM classifier, polynomial kernel: --------------------
# Accuracy and confusion matrix: 0.68
# [[13  7]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.62
# 10 fold cross-validation -> Accuracy: 0.78
# -------------------- SVM classifier, RBF function kernel: --------------------
# Accuracy and confusion matrix: 0.78
# [[17  3]
#  [ 6 14]]
# 5 fold cross-validation -> Accuracy: 0.59
# 10 fold cross-validation -> Accuracy: 0.78

# %%
np.random.seed(1)
# number of test case
tc = 5
sss = StratifiedShuffleSplit(n_splits=tc, test_size=.25, random_state=1)
sss.get_n_splits(features, labels)
for train_index, test_index in sss.split(features, labels):
    print ('!--------------------!--------------------!--------------------!--------------------!--------------------!')
    print("Test using:", test_index)
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = labels[train_index], labels[test_index]

    #Fit the model for the data
#     clf.fit(X_train, y_train)
    clf_nb.fit(X_train, y_train)

    #Make the prediction
    y_pred = clf_nb.predict(X_test)
    
    print ('--- --- --- --- --- --- ---')
    # Model Accuracy: 
    print("Accuracy: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
        
    # Confusion matrix
    print(metrics.confusion_matrix(y_test,y_pred))
        
    # Cross-validation 5 folds        
    accuracies = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 5)
    print("5 fold cross-validation: {:.2f}".format(accuracies5.mean()))
    # Cross-validation 10 folds
    accuracies10 = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 10, scoring='accuracy')    
    print("10 fold cross-validation -> Accuracy: {:.2f}".format(accuracies10.mean()))
# Out:
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [123  50 172   1 106 110 193 120 152  29  96  11 130 136 185  28  13 107
#    5 102 176 113  85 191  18 143  76  71  14 177   9 170  64  75 145  16
#   25  79   6 168  37 175  20 190 121 157  68  72  12 194]
# --- --- --- --- --- --- ---
# Accuracy: 0.84
# [[21  4]
#  [ 4 21]]
# 5 fold cross-validation: 0.57
# 10 fold cross-validation -> Accuracy: 0.61
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 37 133 182 108  11 130  87   6  52 199  36 195  46 127 188  32 109 140
#   50  21  58   0 138 148 105  22 146  16 178 103  63 107  92  35 181 137
#   70 169 177  27  93 151 167  49  18 191  75  28 143  14]
# --- --- --- --- --- --- ---
# Accuracy: 0.72
# [[19  6]
#  [ 8 17]]
# 5 fold cross-validation: 0.57
# 10 fold cross-validation -> Accuracy: 0.61
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 83   1 167  12  94  30  89 159  47  64 101 193   7 143 105  39 174  21
#  153  85 142  97 131 111 100  37 103 126 166  90  32  15 139 113 148 190
#   57 157  18  38 188 195  52 156  77 154 175  19  42  36]
# --- --- --- --- --- --- ---
# Accuracy: 0.68
# [[22  3]
#  [13 12]]
# 5 fold cross-validation: 0.57
# 10 fold cross-validation -> Accuracy: 0.63
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 61  88 123  46  35 153  19  18  58 159  85 157 155  59 105   7  29 173
#  170   9 124 120  94  99  40 127  21  82  51 169  27 182 179 178 177 151
#  158 183 142  67 136  45   0 180 163  71  54  41 191 154]
# --- --- --- --- --- --- ---
# Accuracy: 0.66
# [[18  7]
#  [10 15]]
# 5 fold cross-validation: 0.57
# 10 fold cross-validation -> Accuracy: 0.60
# !--------------------!--------------------!--------------------!--------------------!--------------------!
# Test using: [ 70  53 131  83 125 174  49  21  30  28  32  81 187 149   1  37  73  76
#  183  48 109 123  40 163  34  99 111 193  82 168 142 140  86  80  88   0
#  195 190   3 169 105 188 118 196 179  33  22 138 146 132]
# --- --- --- --- --- --- ---
# Accuracy: 0.74
# [[21  4]
#  [ 9 16]]
# 5 fold cross-validation: 0.57
# 10 fold cross-validation -> Accuracy: 0.57
